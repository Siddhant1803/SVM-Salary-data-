# %% [raw]
# 1) Prepare a classification model using SVM for salary data
#
# Data Description:
#
# age -- age of a person
# workclass	-- A work class is a grouping of work
# education	-- Education of an individuals
# maritalstatus -- Marital status of an individulas
# occupation	 -- occupation of an individuals
# relationship --
# race --  Race of an Individual
# sex --  Gender of an Individual
# capitalgain --  profit received from the sale of an investment
# capitalloss	-- A decrease in the value of a capital asset
# hoursperweek -- number of hours work per week
# native -- Native of an individual
# Salary -- salary of an individual

# %%
#importing common library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading data
#train data
X=pd.read_csv("/content/SalaryData_Train(1).csv.crdownload")
X
# Out:
#       age          workclass      education  educationno        maritalstatus  \
# 0      39          State-gov      Bachelors           13        Never-married
# 1      50   Self-emp-not-inc      Bachelors           13   Married-civ-spouse
# 2      38            Private        HS-grad            9             Divorced
# 3      53            Private           11th            7   Married-civ-spouse
# 4      28            Private      Bachelors           13   Married-civ-spouse
# ...   ...                ...            ...          ...                  ...
# 5531   52            Private        HS-grad            9   Married-civ-spouse
# 5532   29            Private        HS-grad            9   Married-civ-spouse
# 5533   29            Private        HS-grad            9   Married-civ-spouse
# 5534   25          Local-gov   Some-college           10   Married-civ-spouse
# 5535   21            Private   Some-college           10        Never-married
#
# ...

# %%
#test data
Y=pd.read_csv("/content/SalaryData_Test(1).csv")
Y
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
#concatenation of above data set
frame = [X,Y]
raw_df = pd.concat(frame)
display(raw_df)
# Out:
#        age          workclass   education  educationno        maritalstatus  \
# 0       39          State-gov   Bachelors           13        Never-married
# 1       50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2       38            Private     HS-grad            9             Divorced
# 3       53            Private        11th            7   Married-civ-spouse
# 4       28            Private   Bachelors           13   Married-civ-spouse
# ...    ...                ...         ...          ...                  ...
# 15055   33            Private   Bachelors           13        Never-married
# 15056   39            Private   Bachelors           13             Divorced
# 15057   38            Private   Bachelors           13   Married-civ-spouse
# 15058   44            Private   Bachelors           13             Divorced
# 15059   35       Self-emp-inc   Bachelors           13   Married-civ-spouse
#
# ...

# %%
raw_df.reset_index(inplace=True)

# %%
raw_df
# Out:
#        index  age          workclass   education  educationno  \
# 0          0   39          State-gov   Bachelors           13
# 1          1   50   Self-emp-not-inc   Bachelors           13
# 2          2   38            Private     HS-grad            9
# 3          3   53            Private        11th            7
# 4          4   28            Private   Bachelors           13
# ...      ...  ...                ...         ...          ...
# 20591  15055   33            Private   Bachelors           13
# 20592  15056   39            Private   Bachelors           13
# 20593  15057   38            Private   Bachelors           13
# 20594  15058   44            Private   Bachelors           13
# 20595  15059   35       Self-emp-inc   Bachelors           13
#
#              maritalstatus          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# ...

# %%
#information
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20596 entries, 0 to 20595
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          20596 non-null  int64
#  1   age            20596 non-null  int64
#  2   workclass      20596 non-null  object
#  3   education      20596 non-null  object
#  4   educationno    20596 non-null  int64
#  5   maritalstatus  20596 non-null  object
#  6   occupation     20596 non-null  object
#  7   relationship   20596 non-null  object
#  8   race           20595 non-null  object
#  9   sex            20595 non-null  object
#  10  capitalgain    20595 non-null  float64
#  11  capitalloss    20595 non-null  float64
#  12  hoursperweek   20595 non-null  float64
#  13  native         20595 non-null  object
#  14  Salary         20595 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 2.4+ MB

# %% [markdown]
# All data types are correct.

# %%
#describe
raw_df.describe()
# Out:
#               index           age   educationno   capitalgain   capitalloss  \
# count  20596.000000  20596.000000  20596.000000  20595.000000  20595.000000
# mean    6249.521752     38.681880     10.113274   1105.312891     90.035251
# std     4354.812755     13.306074      2.552224   7583.805698    407.150243
# min        0.000000     17.000000      1.000000      0.000000      0.000000
# 25%     2574.000000     28.000000      9.000000      0.000000      0.000000
# 50%     5148.500000     37.000000     10.000000      0.000000      0.000000
# 75%     9910.250000     47.000000     13.000000      0.000000      0.000000
# max    15059.000000     90.000000     16.000000  99999.000000   3770.000000
#
#        hoursperweek
# count  20595.000000
# mean      40.984414
# std       11.945349
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
#checking null values
raw_df.isnull().sum()
# Out:
# index            0
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             1
# sex              1
# capitalgain      1
# capitalloss      1
# hoursperweek     1
# native           1
# Salary           1
# dtype: int64

# %% [markdown]
# There is one null value present in each columns from race to salary.

# %%
#Imputation NA values
raw_df['race']=raw_df['race'].fillna(raw_df['race'].mode())
raw_df['sex']=raw_df['sex'].fillna(raw_df['sex'].mode())
raw_df['capitalgain']=raw_df['capitalgain'].fillna(raw_df['capitalgain'].mean())
raw_df['capitalloss']=raw_df['capitalloss'].fillna(raw_df['capitalloss'].mean())
raw_df['hoursperweek']=raw_df['hoursperweek'].fillna(raw_df['hoursperweek'].mean())
raw_df['native']=raw_df['native'].fillna(raw_df['native'].mode())
raw_df['Salary']=raw_df['Salary'].fillna(raw_df['Salary'].mode())

# %%
raw_df.isnull().sum()
# Out:
# index            0
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             1
# sex              1
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           1
# Salary           1
# dtype: int64

# %%
obj_col = raw_df[['race']]
obj_col.isnull().sum()
# Out:
# race    1
# dtype: int64

# %%
obj_col = obj_col.fillna(obj_col.mode().iloc[0])

# %%
obj_col.isnull().sum()
# Out:
# race    0
# dtype: int64

# %%
obj_col1 = raw_df[['sex']]
obj_col1=obj_col1.fillna(obj_col1.mode().iloc[0])
obj_col1.isnull().sum()
# Out:
# sex    0
# dtype: int64

# %%
obj_col2=raw_df[['native']]
obj_col2=obj_col2.fillna(obj_col2.mode().iloc[0])
obj_col2.isnull().sum()
# Out:
# native    0
# dtype: int64

# %%
obj_col3 = raw_df[['Salary']]
obj_col3= obj_col3.fillna(obj_col3.mode().iloc[0])
obj_col3.isnull().sum()
# Out:
# Salary    0
# dtype: int64

# %%
raw_df['race']=obj_col.values

# %%
raw_df['sex']=obj_col1.values
raw_df['native']=obj_col2.values
raw_df['Salary']=obj_col3.values

# %%
raw_df.isnull().sum()
# Out:
# index            0
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20596 entries, 0 to 20595
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          20596 non-null  int64
#  1   age            20596 non-null  int64
#  2   workclass      20596 non-null  object
#  3   education      20596 non-null  object
#  4   educationno    20596 non-null  int64
#  5   maritalstatus  20596 non-null  object
#  6   occupation     20596 non-null  object
#  7   relationship   20596 non-null  object
#  8   race           20596 non-null  object
#  9   sex            20596 non-null  object
#  10  capitalgain    20596 non-null  float64
#  11  capitalloss    20596 non-null  float64
#  12  hoursperweek   20596 non-null  float64
#  13  native         20596 non-null  object
#  14  Salary         20596 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 2.4+ MB

# %%
#check for duplicates
raw_df.duplicated().sum()
# Out:
# 0

# %%
#changing column name
raw_df = raw_df.rename({'Salary':'salary'},axis=1)
raw_df.head(1)
# Out:
#    index  age   workclass   education  educationno   maritalstatus  \
# 0      0   39   State-gov   Bachelors           13   Never-married
#
#       occupation    relationship    race    sex  capitalgain  capitalloss  \
# 0   Adm-clerical   Not-in-family   White   Male       2174.0          0.0
#
#    hoursperweek          native  salary
# 0          40.0   United-States   <=50K

# %%
#dropping index column
df=raw_df.drop('index',axis=1)

# %%
df.head()
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
# 2   38            Private     HS-grad            9             Divorced
# 3   53            Private        11th            7   Married-civ-spouse
# 4   28            Private   Bachelors           13   Married-civ-spouse
#
#            occupation    relationship    race      sex  capitalgain  \
# 0        Adm-clerical   Not-in-family   White     Male       2174.0
# 1     Exec-managerial         Husband   White     Male          0.0
# 2   Handlers-cleaners   Not-in-family   White     Male          0.0
# 3   Handlers-cleaners         Husband   Black     Male          0.0
# 4      Prof-specialty            Wife   Black   Female          0.0
#
#    capitalloss  hoursperweek          native  salary
# 0          0.0          40.0   United-States   <=50K
# ...

# %% [markdown]
# Outliers detection

# %%
ot=df.copy()
fig,axes = plt.subplots(5,1,figsize=(15,18),sharex=False,sharey=False)
sns.boxplot(x='age',data=ot,palette='crest',ax=axes[0])
sns.boxplot(x='educationno',data=ot,palette='crest',ax=axes[1])
sns.boxplot(x='capitalgain',data=ot,palette='crest',ax=axes[2])
sns.boxplot(x='capitalloss',data=ot,palette='crest',ax=axes[3])
sns.boxplot(x='hoursperweek',data=ot,palette='crest',ax=axes[4])

# %% [markdown]
# There are lot of outliers present in the dataframe but we can't drop them because they are present in a very large quantity and can be important for model building

# %% [markdown]
# descriptive analysis

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'salary'],
#       dtype='object')

# %%
numerical_col = df[['age','educationno','capitalgain','capitalloss','hoursperweek']]
object_col = df[['workclass', 'education','maritalstatus','occupation', 'relationship', 'race', 'sex','native', 'salary']]

# %%
#data visualization
for feature in numerical_col.columns:
    data=numerical_col.copy()
    data[feature].hist(bins=10)
    plt.ylabel('count')
    plt.xlabel(feature)
    plt.show()

# %% [markdown]
# *Most of the people working are of age between 20-60 and also there are people who with age beyond 60 are still working.
# *Most of the people suffering from capitalloss which is around 500.
# *Capitalgain is around 10,000.
# *Most of the people are working 40hrs per week and there are also some people who works beyond 60 hrs.

# %%
for feature in object_col.columns:
    data=object_col.copy()
    fig=plt.figure(figsize=(10,6))
    sns.countplot(data[feature])
    plt.xticks(fontsize = 10,rotation=90)
    plt.ylabel('count')
    plt.title(feature)
    plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# From the above salary plot we can see that most of the people are with salary greater than or equal to 50k.

# %%
#correlation
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# No colinearity present in the numercal variable.

# %%
sns.pairplot(df)

# %% [markdown]
# Numercal varible are independent of each other.

# %% [markdown]
# Analyzing salary with respect catogorical feature

# %%
object_col.columns
# Out:
# Index(['workclass', 'education', 'maritalstatus', 'occupation', 'relationship',
#        'race', 'sex', 'native', 'salary'],
#       dtype='object')

# %%
df['salary'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
#salary with respect to workclass
j_df = pd.DataFrame()
j_df[' <=50K'] = df[df['salary'] == ' <=50K']['workclass'].value_counts()
j_df[' >50K'] = df[df['salary'] == ' >50K']['workclass'].value_counts()
j_df
# Out:
#                     <=50K   >50K
#  Private            11809   3295
#  Self-emp-not-inc    1282    477
#  Local-gov           1018    398
#  State-gov            658    241
#  Federal-gov          384    245
#  Self-emp-inc         345    436
#  Without-pay            6      2

# %%
j_df.plot(kind='bar',figsize=(9,5))

# %%
#salary with respective to education
a_df = pd.DataFrame()
a_df[' <=50K'] = df[df['salary'] == ' <=50K']['education'].value_counts()
a_df[' >50K'] = df[df['salary'] == ' >50K']['education'].value_counts()
a_df
# Out:
#                 <=50K   >50K
#  HS-grad         5619   1130
#  Some-college    3568    884
#  Bachelors       2024   1438
#  11th             727     42
#  Assoc-voc        677    220
#  Masters          542    639
#  10th             519     38
#  Assoc-acdm       483    197
#  7th-8th          340     27
#  9th              292     19
#  12th             240     17
#  5th-6th          200     12
#  1st-4th           95      3
#  Prof-school       82    258
#  Doctorate         62    169
#  Preschool         32      1

# %%
a_df.plot(kind='bar',figsize=(8,5))

# %%
#salary with respect to maritalstatus
b_df = pd.DataFrame()
b_df[' <=50K'] = df[df['salary'] == ' <=50K']['maritalstatus'].value_counts()
b_df[' >50K'] = df[df['salary'] == ' >50K']['maritalstatus'].value_counts()
b_df
# Out:
#                          <=50K   >50K
#  Never-married            6341    316
#  Married-civ-spouse       5211   4367
#  Divorced                 2574    281
#  Separated                 598     45
#  Widowed                   544     52
#  Married-spouse-absent     223     29
#  Married-AF-spouse          11      4

# %%
b_df.plot(kind='bar',figsize=(7,5))

# %%
#salary with respect to occupation 
c_df = pd.DataFrame()
c_df[' <=50K'] = df[df['salary'] == ' <=50K']['occupation'].value_counts()
c_df[' >50K'] = df[df['salary'] == ' >50K']['occupation'].value_counts()
c_df
# Out:
#                      <=50K   >50K
#  Adm-clerical         2148    343
#  Craft-repair         2109    620
#  Other-service        2095     88
#  Sales                1847    680
#  Prof-specialty       1471   1222
#  Exec-managerial      1434   1286
#  Machine-op-inspct    1214    170
#  Handlers-cleaners     861     69
#  Transport-moving      821    220
#  Farming-fishing       587     75
#  Tech-support          486    188
#  Protective-serv       317    128
#  Priv-house-serv       108      2
#  Armed-Forces            4      3

# %%
c_df.plot(kind='bar',figsize=(8,5))

# %%
#salary with respect to relationship
d_df = pd.DataFrame()
d_df[' <=50K'] = df[df['salary'] == ' <=50K']['relationship'].value_counts()
d_df[' >50K'] = df[df['salary'] == ' >50K']['relationship'].value_counts()
d_df
# Out:
#                   <=50K    >50K
#  Not-in-family     4846   547.0
#  Husband           4610  3873.0
#  Own-child         2921    54.0
#  Unmarried         2023   129.0
#  Other-relative     608    22.0
#  Wife               493   469.0
#  Not-in-              1     NaN

# %%
d_df.plot(kind='bar',figsize=(8,5))

# %%
#salary with respect to race
f_df = pd.DataFrame()
f_df[' <=50K'] = df[df['salary'] == ' <=50K']['race'].value_counts()
f_df[' >50K'] = df[df['salary'] == ' >50K']['race'].value_counts()
f_df
# Out:
#                       <=50K   >50K
#  White                13075   4643
#  Black                 1720    236
#  Asian-Pac-Islander     398    165
#  Amer-Indian-Eskimo     179     24
#  Other                  130     26

# %%
f_df.plot(kind='bar',figsize=(8,5))

# %%
#salary with respect to sex
h_df = pd.DataFrame()
h_df[' <=50K'] = df[df['salary'] == ' <=50K']['sex'].value_counts()
h_df[' >50K'] = df[df['salary'] == ' >50K']['sex'].value_counts()
h_df
# Out:
#           <=50K   >50K
#  Male      9608   4316
#  Female    5894    778

# %%
h_df.plot(kind='bar',figsize=(8,5))

# %%
#salary with respect to native
n_df = pd.DataFrame()
n_df[' <=50K'] = df[df['salary'] == ' <=50K']['native'].value_counts()
n_df[' >50K'] = df[df['salary'] == ' >50K']['native'].value_counts()
n_df
# Out:
#                               <=50K    >50K
#  United-States                14078  4748.0
#  Mexico                         391    21.0
#  Philippines                     88    32.0
#  Puerto-Rico                     76    11.0
#  Germany                         68    22.0
#  El-Salvador                     62     3.0
#  Canada                          50    36.0
#  Cuba                            49    11.0
#  China                           40    20.0
#  Dominican-Republic              40     5.0
#  India                           35    25.0
#  Guatemala                       34     1.0
#  South                           34     5.0
#  Poland                          31     7.0
#  Japan                           31    11.0
#  Jamaica                         31     7.0
#  England                         30    21.0
#  Columbia                        30     2.0
#  Italy                           29    15.0
#  Vietnam                         28     3.0
# ...

# %%
n_df.plot(kind='bar',figsize=(15,5))

# %%
df.head(2)
# Out:
#    age          workclass   education  educationno        maritalstatus  \
# 0   39          State-gov   Bachelors           13        Never-married
# 1   50   Self-emp-not-inc   Bachelors           13   Married-civ-spouse
#
#          occupation    relationship    race    sex  capitalgain  capitalloss  \
# 0      Adm-clerical   Not-in-family   White   Male       2174.0          0.0
# 1   Exec-managerial         Husband   White   Male          0.0          0.0
#
#    hoursperweek          native  salary
# 0          40.0   United-States   <=50K
# 1          13.0   United-States   <=50K

# %%
#lebel encoding for categorical data
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['workclass']=le.fit_transform(df['workclass'])
df['education']=le.fit_transform(df['education'])
df['maritalstatus']=le.fit_transform(df['maritalstatus'])
df['occupation']=le.fit_transform(df['occupation'])
df['relationship']=le.fit_transform(df['relationship'])
df['race']=le.fit_transform(df['race'])
df['sex']=le.fit_transform(df['sex'])
df['native']=le.fit_transform(df['native'])
df['salary']=le.fit_transform(df['salary'])

# %%
df.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   39          5          9           13              4           0
# 1   50          4          9           13              2           3
# 2   38          2         11            9              0           5
# 3   53          2          1            7              2           5
# 4   28          2          9           13              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             2     4    1       2174.0          0.0          40.0      37
# 1             0     4    1          0.0          0.0          13.0      37
# 2             2     4    1          0.0          0.0          40.0      37
# 3             0     2    1          0.0          0.0          40.0      37
# 4             6     2    0          0.0          0.0          40.0       4
#
#    salary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
numerical_col.columns
# Out:
# Index(['age', 'educationno', 'capitalgain', 'capitalloss', 'hoursperweek'], dtype='object')

# %%
#Standardizing data
from sklearn.preprocessing import StandardScaler

# %%
scale = StandardScaler()
df[['age', 'educationno', 'capitalgain', 'capitalloss', 'hoursperweek']]=scale.fit_transform(df[['age', 'educationno', 'capitalgain', 'capitalloss', 'hoursperweek']])

# %%
df.head()
# Out:
#         age  workclass  education  educationno  maritalstatus  occupation  \
# 0  0.023908          5          9     1.131090              4           0
# 1  0.850619          4          9     1.131090              2           3
# 2 -0.051247          2         11    -0.436208              0           5
# 3  1.076085          2          1    -1.219857              2           5
# 4 -0.802802          2          9     1.131090              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             2     4    1     0.140924    -0.221146     -0.082414      37
# 1             0     4    1    -0.145754    -0.221146     -2.342817      37
# 2             2     4    1    -0.145754    -0.221146     -0.082414      37
# 3             0     2    1    -0.145754    -0.221146     -0.082414      37
# 4             6     2    0    -0.145754    -0.221146     -0.082414       4
#
#    salary
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#define input variable
X=df.iloc[:,:13]
X.head()
# Out:
#         age  workclass  education  educationno  maritalstatus  occupation  \
# 0  0.023908          5          9     1.131090              4           0
# 1  0.850619          4          9     1.131090              2           3
# 2 -0.051247          2         11    -0.436208              0           5
# 3  1.076085          2          1    -1.219857              2           5
# 4 -0.802802          2          9     1.131090              2           9
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0             2     4    1     0.140924    -0.221146     -0.082414      37
# 1             0     4    1    -0.145754    -0.221146     -2.342817      37
# 2             2     4    1    -0.145754    -0.221146     -0.082414      37
# 3             0     2    1    -0.145754    -0.221146     -0.082414      37
# 4             6     2    0    -0.145754    -0.221146     -0.082414       4

# %%
#define target varible
Y=df['salary']
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: salary, dtype: int64

# %%
Y.value_counts()
# Out:
# 0    15502
# 1     5094
# Name: salary, dtype: int64

# %%
#splitting data using train_test_split
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.33,random_state=10,stratify=Y)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((13799, 13), (13799,), (6797, 13), (6797,))

# %%
#checking if our model able to detect minority class or not on default parameters
#importing svm
from sklearn import svm
from sklearn.svm import SVC

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import  accuracy_score

# %%
def print_score(clf, x_train, y_train, x_test, y_test, train=True):
    if train:
        pred = clf.predict(x_train)
        clf_report = pd.DataFrame(classification_report(y_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_train, pred)}\n")
        
    elif train==False:
        pred = clf.predict(x_test)
        clf_report = pd.DataFrame(classification_report(y_test, pred, output_dict=True))
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

# %%
rf_clf = SVC()
rf_clf.fit(x_train, y_train)

print_score(rf_clf, x_train, y_train, x_test, y_test, train=True)
print_score(rf_clf, x_train, y_train, x_test, y_test, train=False)
# Out:
# Train Result:
# ...
# Accuracy Score: 80.33%
# _______________________________________________
# CLASSIFICATION REPORT:
#                       0            1  accuracy     macro avg  weighted avg
# precision      0.799828     0.847761  0.803319      0.823795      0.811684
# recall         0.985269     0.249634  0.803319      0.617451      0.803319
# f1-score       0.882916     0.385695  0.803319      0.634306      0.759935
# support    10386.000000  3413.000000  0.803319  13799.000000  13799.000000
# _______________________________________________
# Confusion Matrix:
#  [[10233   153]
#  [ 2561   852]]
#
# Test Result:
# ...
# Accuracy Score: 80.12%
# _______________________________________________
# CLASSIFICATION REPORT:
#                      0            1  accuracy    macro avg  weighted avg
# precision     0.799427     0.823529  0.801236     0.811478      0.805388
# recall        0.982408     0.249851  0.801236     0.616130      0.801236
# ...

# %% [markdown]
# Observation- From the above result of recall we can infer that our model is unable to detect minority class properly.therefore our data is imbalaced.

# %% [markdown]
#  ### Handling imbalance data using SMOTE based technique

# %%
#importing necessary library 
from imblearn.over_sampling import SMOTE
from collections import Counter

counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using SMOTE
smt = SMOTE()
x_train_sm, y_train_sm = smt.fit_resample(x_train, y_train)

counter = Counter(y_train_sm)
print('After',counter)
# Out:
# Before Counter({0: 10386, 1: 3413})
# After Counter({0: 10386, 1: 10386})

# %%
#ADASYN
#library
from imblearn.over_sampling import ADASYN
counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using ADASYN
ada = ADASYN(random_state=10)
x_train_ada, y_train_ada = ada.fit_resample(x_train, y_train)

counter = Counter(y_train_ada)
print('After',counter)
# Out:
# Before Counter({0: 10386, 1: 3413})
# After Counter({1: 10812, 0: 10386})

# %%
#Hybridization: SMOTE + Tomek Links
#library 
from imblearn.combine import SMOTETomek
counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using SMOTE + Tomek
smtom = SMOTETomek(random_state=139)
x_train_smtom, y_train_smtom = smtom.fit_resample(x_train, y_train)

counter = Counter(y_train_smtom)
print('After',counter)
# Out:
# Before Counter({0: 10386, 1: 3413})
# After Counter({0: 10074, 1: 10074})

# %%
#Hybridization: SMOTE + ENN
#library
from imblearn.combine import SMOTEENN
counter = Counter(y_train)
print('Before',counter)
#oversampling the train dataset using SMOTE + ENN
smenn = SMOTEENN()
x_train_smenn, y_train_smenn = smenn.fit_resample(x_train, y_train)

counter = Counter(y_train_smenn)
print('After',counter)
# Out:
# Before Counter({0: 10386, 1: 3413})
# After Counter({1: 7653, 0: 7205})

# %% [markdown]
# #### Performance Analysis after Resampling

# %%
sampled_data = {
    'ACTUAL':[x_train, y_train],
    'SMOTE':[x_train_sm, y_train_sm],
    'ADASYN':[x_train_ada, y_train_ada],
    'SMOTE_TOMEK':[x_train_smtom, y_train_smtom],
    'SMOTE_ENN':[x_train_smenn, y_train_smenn]
}

# %%
def test_eval(clf_model, X_test, y_test, algo=None, sampling=None):
    # Test set prediction
    y_prob=clf_model.predict_proba(X_test)
    y_pred=clf_model.predict(X_test)

    print('Confusion Matrix')
    print('='*60)
    #plot_confusion_matrix(clf_model, X_test, y_test)  
    #plt.show() 
    print(confusion_matrix(y_test,y_pred),"\n")
    print('Classification Report')
    print('='*60)
    print(classification_report(y_test,y_pred),"\n")
    
    return algo,sampling

# %%
model_params = {

    'SVC' : {
        'model' : SVC(probability=True),
        'params' :[ {'C':[1], 'kernel':['linear']}]
    }
}

# %%
#importing necessary libraries
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
from tqdm.notebook import tqdm_notebook

# %%
cv = StratifiedKFold(n_splits=5, random_state=100, shuffle=True)
output = []
for model , model_hp in tqdm_notebook(model_params.items(), desc = 'Loop 1'):
    for resam , data in tqdm_notebook(sampled_data.items(), desc = 'Loop 2'):
        clf = RandomizedSearchCV(model_hp['model'], model_hp['params'],cv = cv, scoring='accuracy', n_jobs=-1 )
        clf.fit(data[0], data[1])
        clf_best = clf.best_estimator_
        print('x'*60)
        print(model+' with ' + resam)
        print('='*60)
        output.append(test_eval(clf_best, x_test, y_test, model, resam))
# Out:
# ...
# Loop 2:   0%|          | 0/5 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:292: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# SVC with ACTUAL
# ...
# Confusion Matrix
# ...
# [[4932  184]
#  [1084  597]]
#
# Classification Report
# ...
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.89      5116
#            1       0.76      0.36      0.48      1681
#
#     accuracy                           0.81      6797
#    macro avg       0.79      0.66      0.69      6797
# weighted avg       0.81      0.81      0.79      6797
# /usr/local/lib/python3.8/dist-packages/sklearn/model_selection/_search.py:292: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
# ...

# %%
from tqdm.notebook import tqdm_notebook
import time
for i in tqdm_notebook(range(10), desc = 'Progress using tqdm_notebook()'):
    time.sleep(0.5)
# Out:
# Progress using tqdm_notebook():   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# the Hybridization technique using SMOTE_Tomek gave the best results we are going to use it further

# %%
counter = Counter(y_train)
print('Before',counter)
# oversampling the train dataset using SMOTE + Tomek
smtom = SMOTETomek(random_state=139)
x_train_smtom, y_train_smtom = smtom.fit_resample(x_train, y_train)

counter = Counter(y_train_smtom)
print('After',counter)
# Out:
# Before Counter({0: 10386, 1: 3413})
# After Counter({0: 10074, 1: 10074})

# %%
x_train,x_test,y_train,y_test = train_test_split(x_train_smtom,y_train_smtom,test_size=0.3,random_state=1, stratify=y_train_smtom)

counter = Counter(y_train_smtom)
print('Before',counter)
counter = Counter(y_train)
print('After',counter)
print("Shape of X_train: ",x_train.shape)
print("Shape of X_test: ", x_test.shape)
print("Shape of y_train: ",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Before Counter({0: 10074, 1: 10074})
# After Counter({0: 7052, 1: 7051})
# Shape of X_train:  (14103, 13)
# Shape of X_test:  (6045, 13)
# Shape of y_train:  (14103,)
# Shape of y_test (6045,)

# %% [markdown]
# #### SVM using default Parameter.

# %%
classifier = SVC()
classifier.fit(x_train, y_train)

pred = classifier.predict(x_test)

accuracy_score(y_test, pred)
# Out:
# 0.7687344913151365

# %%
# GridSearchCV for optimum hyper parameters taking too long to compute.. so we go with default hyper parameters
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.69      0.75      3022
#            1       0.73      0.85      0.79      3023
#
#     accuracy                           0.77      6045
#    macro avg       0.78      0.77      0.77      6045
# weighted avg       0.78      0.77      0.77      6045

# %%
sns.heatmap(confusion_matrix(y_test, pred), annot=True, fmt='d')

# %%
#ROC score
from sklearn.metrics import roc_auc_score

auc = roc_auc_score(y_test,pred)
print('AUC-ROC Score:',auc)
# Out:
# AUC-ROC Score: 0.768721623082509
